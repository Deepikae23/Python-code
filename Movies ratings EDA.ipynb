# %%
import pandas as pd
movies = pd.read_csv(r'D:\data analyst\nov\Movie-Rating\Movie-Rating.csv')

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.isnull()
# Out:
#       Film  Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 0    False  False                      False               False
# 1    False  False                      False               False
# 2    False  False                      False               False
# 3    False  False                      False               False
# 4    False  False                      False               False
# ..     ...    ...                        ...                 ...
# 554  False  False                      False               False
# 555  False  False                      False               False
# 556  False  False                      False               False
# 557  False  False                      False               False
# 558  False  False                      False               False
#
#      Budget (million $)  Year of release
# 0                 False            False
# 1                 False            False
# 2                 False            False
# ...

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.isnull().sum()
# Out:
# Film                         0
# Genre                        0
# Rotten Tomatoes Ratings %    0
# Audience Ratings %           0
# Budget (million $)           0
# Year of release              0
# dtype: int64

# %%
movies.columns=['Film', 'Genre', 'CriticRating', 'AudienceRatings',
       'BudgetMillion', 'Year']

# %%
movies.head(1)
# Out:
#                     Film   Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer   Comedy            87               81
#
#    BudgetMillion  Year
# 0              8  2009

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillion         Year
# count    559.000000       559.000000     559.000000   559.000000
# mean      47.309481        58.744186      50.236136  2009.152057
# std       26.413091        16.826887      48.731817     1.362632
# min        0.000000         0.000000       0.000000  2007.000000
# 25%       25.000000        47.000000      20.000000  2008.000000
# 50%       46.000000        58.000000      35.000000  2009.000000
# 75%       70.000000        72.000000      65.000000  2010.000000
# max       97.000000        96.000000     300.000000  2011.000000

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies.Genre =movies.Genre.astype('category')
movies.Year =movies.Year.astype('category')

# %%
movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillion
# count    559.000000       559.000000     559.000000
# mean      47.309481        58.744186      50.236136
# std       26.413091        16.826887      48.731817
# min        0.000000         0.000000       0.000000
# 25%       25.000000        47.000000      20.000000
# 50%       46.000000        58.000000      35.000000
# 75%       70.000000        72.000000      65.000000
# max       97.000000        96.000000     300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data= movies, x='CriticRating', y= 'AudienceRatings',kind='reg')

# %%
j = sns.jointplot(data= movies, x='CriticRating', y= 'AudienceRatings',kind='hex')

# %%
m1= sns.distplot(movies.CriticRating)

# %%
m1= sns.distplot(movies.AudienceRatings)

# %%
m1= sns.displot(movies.CriticRating)

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(movies.AudienceRatings, bins = 10)

# %%
sns.set_style('white')
m2 = sns.distplot(movies.AudienceRatings, bins = 15)

# %%
import os

# %%
n1 = plt.hist(movies.AudienceRatings, bins= 10)

# %%
sns.set_style('darkgrid')
n1 = plt.hist(movies.AudienceRatings, bins= 10)

# %%
n1= plt.hist(movies.CriticRating, bins=10)

# %%
plt.hist(movies.BudgetMillion)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillion)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Action'].BudgetMillion)
plt.hist(movies[movies.Genre == 'Comedy'].BudgetMillion)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillion)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillion,\
         movies[movies.Genre == 'Comedy'].BudgetMillion,\
         movies[movies.Genre == 'Thriller'].BudgetMillion,\
         movies[movies.Genre == 'Drama'].BudgetMillion],
         bins = 20, stacked =True)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1= sns.lmplot(data= movies, x='CriticRating', y='AudienceRatings',\
                fit_reg =False)

# %%
vis1= sns.lmplot(data= movies, x='CriticRating', y='AudienceRatings',\
                fit_reg =False , hue='Genre')

# %%
vis1= sns.lmplot(data= movies, x='CriticRating', y='AudienceRatings',\
                fit_reg =False, hue='Genre', aspect=1)

# %%
k1 = sns.kdeplot(x='CriticRating',y='AudienceRatings', data=movies)

# %%
k1 = sns.kdeplot(x='CriticRating',y='AudienceRatings', data=movies, shade=True,shade_lowest=False, cmap='Reds')

# %%
k1 = sns.kdeplot(x='CriticRating',y='AudienceRatings', data=movies,shade_lowest=False, cmap='Greens_r')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(x='BudgetMillion',y='AudienceRatings', data=movies,shade_lowest=False, cmap='Greens_r')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(x='BudgetMillion',y='AudienceRatings', data=movies)

# %%
k2 = sns.kdeplot(x='BudgetMillion',y='CriticRating', data=movies)

# %%
f, axes = plt.subplots(1,2, figsize=(12,6))
k1 = sns.kdeplot(x='BudgetMillion',y='AudienceRatings', data=movies, ax = axes[0])
k2 = sns.kdeplot(x='BudgetMillion',y='CriticRating', data=movies,ax = axes[1])

# %%
axes
# Out:
# array([<Axes: xlabel='BudgetMillion', ylabel='AudienceRatings'>,
#        <Axes: xlabel='BudgetMillion', ylabel='CriticRating'>],
#       dtype=object)

# %%
w = sns.boxplot(x='Genre', y='CriticRating', data=movies)

# %%
z = sns.violinplot(x='Genre', y='CriticRating', data=movies)

# %%
w1 = sns.boxplot(x='Year', y='CriticRating', data=movies[movies.Genre == 'Drama'])

# %%
z = sns.violinplot(x='Year', y='CriticRating', data=movies[movies.Genre == 'Drama'])

# %%
g = sns.FacetGrid(data=movies, row='Genre', col='Year', hue='Genre')

# %%
import seaborn as sns

# %%
plt.scatter(x='Year', y='CriticRating', data=movies)

# %%
g = sns.FacetGrid(data=movies, row='Genre', col='Year', hue='Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRatings')

# %%
g = sns.FacetGrid(data=movies, row='Genre', col='Year', hue='Genre')
g = g.map(plt.hist, 'BudgetMillion')

# %%
g = sns.FacetGrid(data=movies, row='Genre', col='Year', hue='Genre')
kws =dict(s=50, linewidth=0.5, edgecolor ='black')
g = g.map(plt.scatter,'CriticRating', 'AudienceRatings', **kws)

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(x='BudgetMillion',y='AudienceRatings', data=movies, ax = axes[0])
k2 = sns.kdeplot(x='BudgetMillion',y='CriticRating', data=movies,ax = axes[1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])

k4 = sns.kdeplot(x='CriticRating',y='AudienceRatings',shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(x='CriticRating',y='AudienceRatings',cmap='Reds',ax = axes[1,1])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[155], line 4
#       1 sns.set_style('darkgrid')
#       2 f, axes = plt.subplots (2,2, figsize = (15,15))
# ----> 4 k1 = sns.kdeplot(x='BudgetMillion',y='AudienceRatings', data=movies, ax = axes[0])
#       5 k2 = sns.kdeplot(x='BudgetMillion',y='CriticRating', data=movies,ax = axes[1])
#       7 k1.set(xlim=(-20,160))
#
# File ~\anaconda3\Lib\site-packages\seaborn\distributions.py:1679, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1676 if ax is None:
#    1677     ax = plt.gca()
# -> 1679 p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
# ...
